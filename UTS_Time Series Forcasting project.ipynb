# %% [markdown]
# to install all of the packages in a single run:

# %%
lapply(.packages(all.available = TRUE), function(xx) library(xx, character.only = TRUE))
# Out:
# Warning message:
# "package 'acepack' was built under R version 3.6.3"Warning message:
# "package 'ade4' was built under R version 3.6.3"Warning message:
# "package 'adehabitatLT' was built under R version 3.6.3"Loading required package: sp
# Warning message:
# "package 'sp' was built under R version 3.6.3"Loading required package: adehabitatMA
# Warning message:
# "package 'adehabitatMA' was built under R version 3.6.3"Registered S3 methods overwritten by 'adehabitatMA':
#   method                       from
#   print.SpatialPixelsDataFrame sp
#   print.SpatialPixels          sp
# Loading required package: CircStats
# Warning message:
# "package 'CircStats' was built under R version 3.6.3"Loading required package: MASS
# Warning message:
# "package 'MASS' was built under R version 3.6.3"Loading required package: boot
# Warning message:
# "package 'AER' was built under R version 3.6.3"Loading required package: car
# Warning message:
# ...

# %%
library(readxl)
# Out:
# Warning message:
# "package 'readxl' was built under R version 3.6.3"

# %%
mydata <- read_excel("C:/Users/David/OneDrive/Documents/00-University Research Applications/UTS/research 1/nsw/nsw.xlsx")

# %%
head(mydata)
# Out:
#   Time                Precipitation since 9am local time in mm
# 1 2000-01-01 01:00:00 0.0000000
# 2 2000-01-01 01:30:00 0.2672272
# 3 2000-01-01 02:00:00 0.0000000
# 4 2000-01-01 02:30:00 0.2672272
# 5 2000-01-01 03:00:00 0.0000000
# 6 2000-01-01 03:30:00 0.2672272
#   Quality of precipitation since 9am local time Air Temperature in degrees C
# 1 0.5                                           19.50000
# 2 0.5                                           21.79168
# 3 0.5                                           18.30000
# 4 0.5                                           21.79168
# 5 0.5                                           17.30000
# 6 0.5                                           21.79168
#   Quality of air temperature Dew point temperature in degrees C
# 1 0.5                        2.900000
# 2 0.5                        3.390898
# 3 0.5                        2.600000
# 4 0.5                        3.390898
# 5 0.5                        2.900000
# ...

# %%
myts <- ts(mydata[, 2:4], start = c(1981, 1), frequency = 4)

# %%
install.packages(c("ggvis","htmlwidgets","maps","sunburstR", "lattice",
  "predict3d","rgl","rglwidget","plot3Drgl","ggmap","ggplot2","plotly",
  "RColorBrewer","dygraphs","canvasXpress","qgraph","moveVis","ggcharts",
  "igraph","visNetwork","visreg", "VIM", "sjPlot", "plotKML", "squash",
  "rbokeh"), dependencies = TRUE)
# Out:
# Warning message:
# "dependencies 'limma', 'graph' are not available"
#   There are binary versions available but the source versions are later:
#         binary source needs_compilation
# ggplot2  3.3.1  3.3.2             FALSE
# VIM      5.1.1  6.0.0              TRUE
#
#   Binaries will be installed
# package 'ggvis' successfully unpacked and MD5 sums checked
# package 'htmlwidgets' successfully unpacked and MD5 sums checked
# package 'maps' successfully unpacked and MD5 sums checked
# package 'sunburstR' successfully unpacked and MD5 sums checked
# package 'lattice' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'lattice'"Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\David\Anaconda3\envs\r-tutorial\Lib\R\library\00LOCK\lattice\libs\x64\lattice.dll to C:\Users\David\Anaconda3\envs\r-tutorial\Lib\R\library\lattice\libs\x64\lattice.dll: Permission denied"Warning message:
# ...

# %%
library(fpp2)
# Out:
# Warning message:
# "package 'fpp2' was built under R version 3.6.3"Loading required package: ggplot2
# Loading required package: forecast
# Warning message:
# "package 'forecast' was built under R version 3.6.3"Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Loading required package: fma
# Warning message:
# "package 'fma' was built under R version 3.6.3"
# Attaching package: 'fma'
#
# The following objects are masked from 'package:MASS':
#
#     cement, housing, petrol
#
# Loading required package: expsmooth
# Warning message:
# "package 'expsmooth' was built under R version 3.6.3"

# %%
autoplot(myts, facets = FALSE)
# Out:
# plot without title

# %%
ggAcf(myts)
# Out:
# Warning message:
# "Removed 250 rows containing missing values (geom_segment)."
# plot without title

# %%
autoplot(myts, facets = TRUE)
# Out:
# plot without title

# %%
install.packages("tidyverts")
# Out:
# Warning message:
# "package 'tidyverts' is not available (for R version 3.6.1)"

# %%
library(tidyverse)
library(tsibble)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"-- Attaching packages --------------------------------------- tidyverse 1.3.0 --
# v tibble  3.0.1     v dplyr   1.0.0
# v tidyr   1.1.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# v purrr   0.3.4
# Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'readr' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"Warning message:
# "package 'stringr' was built under R version 3.6.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::id()     masks adehabitatLT::id()
# x dplyr::lag()    masks stats::lag()
# x dplyr::recode() masks car::recode()
# x dplyr::select() masks MASS::select()
# ...

# %%
autoplot(goog)
# Out:
# plot without title

# %%
autoplot(diff(goog))
# Out:
# plot without title

# %%
ggAcf(diff(goog))
# Out:
# plot without title

# %%
autoplot(sunspot.year)
ggAcf(sunspot.year)
# Out:
# plot without title
# plot without title

# %%
maxlag_sunspot <- 1

# %%
autoplot(hyndsight)
# Out:
# plot without title
